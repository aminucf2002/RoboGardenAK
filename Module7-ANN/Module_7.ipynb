# %% [markdown]
# # Perform the following task in the provided editor to complete this mission:
#
# ### Step 1
#
# ### You are given training and test sets from the Credit-G dataset. Write code that uses the Scikit-Learn library to build, train, and test an ANN classifier with the architecture described below.
#
# ### Your code should perform the following tasks to complete this mission.
#
# ### Build the ANN classifier with the following parameters:
#
# ### The network has an input layer and two hidden layers
# ### Each layer has 100 units
# ### Activation function: ReLU
# ### Optimizer: Adam
# ### Number of training epochs: 100
# ### Batch size: 20
# ### random_state=0
# ### Train the network using the training data (x_train and y_train).
# ### Calculate the confusion matrix for the model using the test set (x_test and y_test).
# ### Your code should return the confusion matrix.

# %%
def main():
    from sklearn.datasets import fetch_openml
    dataset = fetch_openml(name='credit-g', version=1, as_frame=True)
    x = dataset.data
    y = dataset.target
    from sklearn.preprocessing import LabelEncoder
    encoder = LabelEncoder()
    y = encoder.fit_transform(y)
    from sklearn.model_selection import train_test_split
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)
    from sklearn.preprocessing import StandardScaler
    scaler = StandardScaler()
    import pandas as pd
    x_train = pd.get_dummies(x_train)
    x_test = pd.get_dummies(x_test)
    x_train, x_test = x_train.align(x_test, join='left', axis=1, fill_value=0)
    x_train = scaler.fit_transform(x_train)
    x_test = scaler.transform(x_test)
    from keras.models import Sequential
    from keras.layers import Dense
    model = Sequential()
    model.add(Dense(units=100, activation='relu'))
    model.add(Dense(units=100, activation='relu'))
    model.add(Dense(units=1, activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    model.fit(x_train, y_train, batch_size=20, epochs=100)
    y_pred = model.predict(x_test)
    y_pred = (y_pred > 0.5)
    from sklearn.metrics import confusion_matrix
    confusion_matrix = confusion_matrix(y_test, y_pred)

    # Write your code here. Do not change any other parts of the code
    from sklearn.metrics import accuracy_score
    print('Accuracy score: ' + str(accuracy_score(y_test,y_pred)*100))
    return confusion_matrix
main()
# Out:
# Epoch 1/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6550 - loss: 0.6258
# Epoch 2/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7538 - loss: 0.4819
# Epoch 3/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8037 - loss: 0.4232
# Epoch 4/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8350 - loss: 0.3771
# Epoch 5/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8525 - loss: 0.3433
# Epoch 6/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8675 - loss: 0.3080
# Epoch 7/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8863 - loss: 0.2779
# Epoch 8/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9025 - loss: 0.2499
# Epoch 9/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9250 - loss: 0.2205
# Epoch 10/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9375 - loss: 0.1927
# Epoch 11/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9500 - loss: 0.1637
# Epoch 12/100
# ...

# %% [markdown]
# # Module 7-2 Editor 2

# %%
# Instructions:

# In this mission, you will work with the Boston Housing dataset to practice regression modeling using Artificial Neural Networks (ANNs).

# Perform the following task in the provided editor to complete this mission:

# Step 1    

# You are given training and test sets from the dataset in the data.csv file. Write code that uses the Scikit-Learn library to build, train, and test an ANN regressor with the architecture described below. Your code should perform the following tasks to complete this mission:

# Build the ANN regressor with the following parameters:

# The network has an input layer and two hidden layers
# Each layer has 100 units
# Activation function: ReLU
# Optimizer: Adam
# Number of training epochs: 100
# Batch size: 20
# random_state=0
# Train the network using the training data (x_train and y_train)
# Calculate the R2 score for the model using the test set (x_test and y_test).
# Your code should return the R2 score.

def main():
  import pandas as pd
x_columns = 13
dataset = pd.read_csv('data.csv')
x = dataset.iloc[:500 , 0: x_columns].values
y = dataset.iloc[:500 , x_columns].values

from sklearn.model_selection
import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

from sklearn.preprocessing
import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
from sklearn.neural_network import 
import MLPRegressor
regressor = MLPRegressor(hidden_layer_sizes=(100,100), max_iter=100, alpha=0.0001,
solver='adam', random_state=1)
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)
from sklearn.metrics
import r2_score
score = r2_score(y_test, y_pred)
# Write your code here.Do not change any other parts of the code# Uncomment the following two lines after completing the mission to run successfully# print(score)# return score
main()
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
